# %% [markdown]
# This notebook extracts the passage/review pairs in the validation set that the model (the model loaded in testing_util) succeeds in matching correctly. Looking at these pairs, as well as the pairs it failed to match can provide some insight into what kinds of features it has learned.

# %%
from dataloading import get_dataset

# %%
_, evalset = get_dataset()
evalset_size = len(evalset)

# %%
from testing_util import tok, get_batch_tokens, model
from util import generate_indices
import torch

def encode_and_val(pass_mbs, rev_mbs):
        with torch.no_grad():
            pass_encs = [model.encodeX(tokens, masks)
                for (tokens, masks) in pass_mbs]
            
            rev_encs = [model.encodeY(tokens, masks)
                for (tokens, masks) in rev_mbs]
        
            test_loss, test_acc = model.cLoss(torch.cat(pass_encs), torch.cat(rev_encs))
        return pass_encs, rev_encs, test_loss, test_acc
    
MB_SIZE = 4

pass_t, pass_m, rev_t, rev_m = get_batch_tokens(evalset, torch.arange(evalset_size))
mb_inds = generate_indices(evalset_size, MB_SIZE, shuffle = False)

pass_mbs = [(pass_t[ind], pass_m[ind]) for ind in mb_inds]
rev_mbs = [(rev_t[ind], rev_m[ind]) for ind in mb_inds]

pass_encs, rev_encs, _, total_acc = encode_and_val(pass_mbs, rev_mbs)
pass_encs = torch.cat(pass_encs)
rev_encs = torch.cat(rev_encs)

print(total_acc)
logits = pass_encs @ rev_encs.T
# Out:
# tensor(0.1800, device='cuda:0')

# %%
success_pairs = []
fail_pairs = []

for i, row in enumerate(logits):
    if row.argmax().item() == i:
        success_pairs.append(evalset[i])
    else:
        fail_pairs.append(evalset[i])

# %%
for i, pair in enumerate(success_pairs):
    print(str(i) + ":" + pair[1])
    print("")
# Out:
# 0:Sam3 seems oddly familiar with Jane0's name. Did she know Jane0 before this evening? Perhaps I missed that.
#
# 1:A comment about height might be rude, but I'm not sure how it could be much other than innocent (or am I too vanilla?)
#
# 2:Setting aside Sam0 'hiding' Sam1's name and their prior relationship from the reader, I do like the way that she teases Sam1 with it
#
# 3:Slightly odd that in an essentially romantic story the writer would have them fall into each others arms and then - nothing. There's definitely a feel of something missing (however slight and brief).
#
# 4:The circularity, back to Sam0 admiring the view, is good - though entirely expected. But expectation is usually a good thing. In my view, it connects the reader to the writer. I don't think the adjective thing is a 'rule' either, but there is some truth in it. 'radiant', 'brilliant' stand out like a sort thumb.
#
# 5:[the predawn night] - if it's predawn then it's night - [the predawn twilight] might work
#
# 6:[her mother and Sam0 Welty together] can be read two ways. Now I'm even more uncertain of the exact role of Sam0 Welty in Sam4's life. Could you hold a stone like a steering wheel?
#
# 7:[he mountains that dwarfed the beaded threads of highway] feels overblown
#
# 8:So I'm assuming she's an exotic dancer. But maybe I'm wrong, and she's more like in a chorus line. I'm looking forward to seeing if my first guess is correct.
#
# 9:Wonderful description of John0's wound.
#
# 10:Funny, that's the school Sam1 went to.
#
# 11:Instead of him being unbelieving, I feel like the emotion he might be feeling is hesitancy to ask if she resorted to a certain type of dancing for money.
#
# 12:with that party.
#
# 13:needs some structuring work.... too many clauses and commas. Jane0 and her daugthers are doing coke in the bedroom. It's as large as a kitchen, with jewelry scattered over the furniture and bed like some....
#
# 14:,girls.
#
# 15:Who is Jane0 a prospect to? Sam0
#
# 16:repeat of the word says. Since it's a short story, maybe different wording to separate the characters?
#
# 17:How did the intern become a new director? I feel like there was a big jump and I missed something.
#
# 18:them. ". Remember Probably a formatting issue? I like the villain putting the greater emphasis on manicures instead of Sam3's wellbeing, but the sudden burst of violence isn't set up. I don't know why it's happening, and it pulls me out of the story a bit.
#
# 19:I was under the impression that guns made quite a bit of mess? Is this a magic gun?
#
# 20:Sam0 yells. Jane0 is running out of the room and Sam0 would want to make sure she is heard.
#
# 21:who's saying this?
#
# 22:Oh, wait, now I'm extra confused. I had assumed that "reconnoiter" was part of the assignment. That's why I thought it might have been the intern speaking the first line of dialogue, like she was asking for clarification regarding the first step of her assignment. Oh! Or is the "her" of the first sentence a distinct person from the intern? If so, that is not at ALL clear.
#
# 23:Wait, what? A roundhouse? That was...unexpected.
#
# 24:Based on the description here, the main character is already in the passage and came across a hole. But I find it difficult to imagine the hole in the passage. Is it a pit in the tunnel? How does the passage look like? I hope my questions will help you to make the setting clear to the reader
#
# 25:I wonder what choice he made? Is he willing to explore? or return to his place? Curious!
#
# 26:Wow, a great twist! Who is that person? A ghost? or a human who stayed in the pit of the passage?
#
# 27:This is interesting. But how does that relevant to the tunnels and passages. It would be more logical if they talk about the treasures stored in the tunnel and any other related information. But Sam2 is explaining something that is out of the scope of the story
#
# 28:The giggle seems out of place, but may not be in that situation.
#
# 29:The manic part seems off as well. Your call.
#
# 30:I think this is a good opening, but I'm going to be a bit nit picky about it: I'm not sure about the repetition of "simple". I see the effect you're going for, but for the first line it stood out to me, and not in a strong way. "A car either has to stop and wait, or run you down..." — I'm not sure what I think about this, either. When the narrator talks to "you," the reader, it can have the effect of throwing the reader out of the story (or hindering their ability to get into it, since this is the beginning). The opening doesn't have the character in it. How about something like that following: "I stood in the middle of the road. Cars would either have to stop or run me down—and it wouldn't do for a hearse carrying the body of a former government official to accelerate towards me." It's not perfect. Possibly, it could use a stronger verb than "stood," for example. But it puts the character and their action front and center, as well as cuts out a lot of unnecessary words, which puts the focus on the dramatic, attention-grabbing parts. Of course, see what others say about it.
#
# 31:Things had simply collided, leaving me the perfect moment." — Just picking another nit, here: "Things" is a little weak. "The route intersected with my walk to work, the police holding everyone back at the crossing so the cars could pass." — I think you can cut those words as unnecessary.
#
# 32:I looked around at..." — You might want to consider revising this to avoid the filtering. John0 had done nothing to earn my respect." — This, too, seems a bit repetitive. I already got that idea from: "We were expected to stand in silence, to be respectful, but Sam0 John0 never let us rest for one moment once he stepped into office. What right did he have to a peaceful forever?" "The police officer guarding the crossing was lookeding the other way, and I had one chance." — Reduces word count and removes a passive verb.
#
# 33:The sky was cloudless and far-reaching above my head." — I wonder if you could rewrite this in a more active way? It stood out, especially because you recently began another paragraph in a similar way: "The tarmac was warm beneath me, cooking in the sun." "I wondered..." — Consider removing the filtering. "I knew I’d be heading to a police station rather than work when they moved me." — I think you can cut all that as unnecessary words. "I was contemplateding whether they’d give me a chance to contact my flatmate and explain my absence at home, when I heard a yell." — Reduces word count and removes a passive verb.
#
# 34:“Allyson,” I saidintroduced myself. “Thank you.” — It's clear that's she's introducing herself.
#
# 35:I always try to avoid saying "seemed" in my own writing. I got a critique once that it knee caps our description and it's stuck with me. You're in charge of this world. Saying "...she was dressed for work, in a pencil skirt..." is much more impactful than having your narrator hem and haw over this description
#
# 36:A bit of a clunky sentence and suggests cameras, not cops, were hauling her away. You've packed a lot into this sentence. It might be improved by making it more bite-size, breaking it up into two sentences. I'm trying to imagine the image: is she face-down or face-up? It's not clear.
#
# 37:I found this opening disorienting, which may have been your intention. At first I wondered how there could be a school building in Sam0 Can children go to Sam0 after all, or do the damned have children? Then I thought Penemue was remembering one of his days on Sam4 through a flashback, and about here is where I finally figured it out. Gormley works in the afterlife, so if that’s where the missing student went, he would know! at the idea of the employees in Sam0 having days off. Of course they'd barbecue. According to our traditional view of the place it’s about the only fun thing they can do down there. So they can cross over, then. At will?
#
# 38:Sounds like Sam1 Sam2 Sam3 Some people believe playing that will land you in hell.
#
# 39:So Penemue is a fallen angel himself!
#
# 40:Penemue throwing words at someone in Chapter 4 prepared me for this.
#
# 41:The driver in the other car.
#
# 42:gently and tenderly are adverbs. Here is my suggestion. -> He grabbed her and placed her in his arms as if she were breakable. His lips parted as he kissed her lips without resistance.
#
# 43:Suggestion: After removing his gloves and mask, he held his breath and with a sprint carried the poisoned bandages into the ward.
#
# 44:Suggestion: But, patients and staff were surrounding him in all directions.
#
# 45:Quickly is an adverb. Suggestion: After he finished talking he swooped in and kissed her again.
#
# 46:Very lucky - in the heart?
#
# 47:I feel this is a bit too romantic for the setting. His words are a bit schmaltzy. A lot, in fact. OTT.
#
# 48:I can't remember how he dies, nor who he's going to use the strychnine on.
#
# 49:I'd cut 'appeared to' And miraculously he hadn't given away that John0 was there in disguise despite dopey John0 confessing to him just before he was tortured!
#
# 50:Nice bit of gory detail here - I like it
#
# 51:No comma after undergarments. Thogh >>> through How real are the times of war when the basics in life are desperately needed - chocolate.
#
# 52:Is John0 driving? If he is, he can't be devouring her with his eyes, or this is going to be a very short chapter indeed. It would be safer - and creepier - if she caught him stealing side glances at her.
#
# 53:The top of her uniform has been ripped, which is really hard to hide. You might want to insert a scene where she uses safety pins in the truck before going back. Also, where is Sam4 who was anxious to get the supplies (and who might ask a little more forcefully where Sam5 is)?
#
# 54:A suggestion : Sam0 should be the one to state Sam1 loves Sam2 while Sam1 would acquiesce. That would plant the seed of rivalry between the two men a little more deeply.
#
# 55:This could be translated as thoughts, with John0 realizing all John1 has done so far was out of his love for her, and pondering the future of their friendship (or whether she can fully trust him now that he knows she loves Sam0
#
# 56:Maybe this part should be told from the perspective of a Sam0 patient/soldier, making a desperate rush to stop what, to him, is a mad orderly committing mass murder in a hospital.
#
# 57:John0 is fresh from firefight and had to throw away his rifle. He should have his pistol ready already, if only because survivors from the hospital tent could have been chasing after him.
#
# 58:people in despair", maybe, to avoid repeating "in ruins"? If you want to use that repetition, maybe something like "the conquered countryside of Sam0 Ruined buildings everywhere, where ruined people lived.
#
# 59:Make clear it is the chateau that is uncommonly picturesque. Sounds like it's the windows.
#
# 60:Omit his head sharply. Or at least omit his head
#
# 61:guard who set. Orderlies who were trying. Coated seems the wrong word . Can you show us the feverishly instead of saying it?
#
# 62:I wonder if these enemy soldiers would look up and see what was passing?
#
# 63:Maybe she would say something more imaginative and flirtatious.
#
# 64:is it the truck or the breeze that reeks of schnapps? One of Sam0's hand-picked lackeys, Amee knew Heirich received special favors. She hoped she wasn’t one of them. — Great last line!
#
# 65:But said he unzipped her pants a couple of paragraphs above this. I was going to comment there that I was thinking she was wearing a nurse's uniform with a skirt.
#
# 66:She had just signed her death warrant. The Sam0 wouldn’t believe her story. They would hunt her down for killing one of their own. - good details to up the already tense situation, giving the reader angst over what will happen to her.
#
# 67:I don't understand how he backs into himself.
#
# 68:not sure if I get: "wished they were better strangers,
#
# 69:it would sound more natural without her addressing his name. Omitting that would sound more natural and realistic dialogue.
#
# 70:ack! was waiting to see what happens. I remember what happened before, but I think I and other critters had suggested Sam0 not kill them, just knock them out or something. Will wait and see!
#
# 71:i'm not sure you need "medical" = maybe just ... - retrieve these items in town. Be sure to get everything on the list. OR Be sure to get everything I ordered. Did she call in her order before hand or is Sam0 going to shop for each item. It could go either way imo
#
# 72:not sure about "her luck wouldn't get to the bottom of the bottle." like run out, I'm assuming, but it's just worded odd for me.
#
# 73:not sure he could kiss and relax after that traumatic drama
#
# 74:John0 pressed the groaning truck - could start a new para to separate his quote from the action of driving and descriptions of the scene
#
# 75:The line Jane0 bristled with disgust" is placed as though it refers to her disgust at all she has to do when she gets back. But I wonder if that's really what you meant.
#
# 76:I'm confused. She's asked "Who's Sam1 and her reply is Sam0 the medic, is actually my old friend" I would expect her, in such a high-pressure situation, to respond as briefly as possible, such as by saying "Captain Sam2 is that auto racer I told you about." Sam3 looked confused. "What are you saying?" Then add the rest about her reasons.
#
# 77:'Scrunched" doesn't sound like something a battle-scarred soldier would do with his eyebrows.
#
# 78:This reads a little awkwardly as if Sam0 LaRue is one person. Maybe "LaRue had already started" can be left out.
#
# 79:the 'said' tag doesn't match with the exclamation mark.
#
# 80:sound-echo, annoying It had to be - not needed; closer POV
#
# 81:just, cards
#
# 82:different different anyway
#
# 83:LaRue doesn't respect Sam0 after all.
#
# 84:How did he know that he'd need a time crystal (for the planetoid event)? I'm wondering what his original goal was? To fix things with the wife?
#
# 85:The attorney must have been horrible.
#
# 86:I wonder if it can be re-calibrated?
#
# 87:I think its stronger without "Much" and I'd switch the order of "could" and "ever" John0 found the end of the world more monotonous than he ever could have imagined. Also you might remove the filter and verb "found" The end of the world proved to be more monotonous than John0 ever could have imagined. and finally get rid of "could" (almost always a good idea): The end of the world proved to be more monotonous than John0 had imagined. First sentences in the short form are crucial, as I am sure you know.
#
# 88:pocket to make sure the crystal was still there, I suggest: pocket to confirm the crystal was still there, The middle description of the TV is perhaps overly complicated and wordy: Maybe: The split screen displayed the incoming planetoid on one side, a digital display showing fifty-nine minutes to impact. The other half showed the Pope administering final mass. John0 would have thought he was watching one of the Sam0 Sam1's celebrations in Sam2 Sam3 except instead of waiting for a new year, and this could be simplified to: It was like watching one of the Sam0 Sam1's celebrations in Sam2 Sam3 except instead of waiting for a new year,
#
# 89:For what must have been the hundredth time by now, he took in her features with regret. lose "what must have been" and "by now" For the hundredth time, he took in her features with regret. What had once been long, flowing blonde hair was now graying well before its time, and falling out to leave a receding hairline like a balding man. trim this too I think: Once long, flowing blonde hair was now graying and falling out, her hairline receding like a balding man. (although I am not fond of the simile; its too similar)
#
# 90:overly complex way of saying this I think, with all the negatives: “I doubt that,” said LaRue. “It's because we are headed for hell that we're scared shitless of what’s waiting for us on the other side.” Also a sudden intrusion here from LaRue, who has not yet been introduced.
#
# 91:I wonder if Jane0 should be mentioned sooner with Sam5 to set up the scene. smoke only a druggie could avoid gagging on This makes me think Jane0 is pretty hardcore.
#
# 92:snap his neck like a pretzel Twist goes better with pretzel. The convict wouldn’t likely kill him, because as far as he was concerned only John0 knew how to use the time crystal. -> The convict wouldn’t likely kill him because as far as he was concerned, only John0 knew how to use the time crystal.
#
# 93:He let out a breath of relief as LaRue returned to his stool. -> As LaRue returned to his stool, he let out a breath of relief. This feels more chronological.
#
# 94:The sound of shuffling cards -> The sound of cards shuffling This sounds better to me. Sam0 seems to be easily agitated.
#
# 95:John0 wondered which one of the two -> John0 wondered which one of them Since this is about John0 wondering and not the narrator.
#
# 96:The scrawny man’s face went blank. The expression feels a bit anti-climatic. It's an expression I expect from someone lost in thought. The man’s head hit with a thunk, sounding like someone tapping a watermelon at the supermarket. I want to know more about LaRue or Ducky here than get a watermelon image. The meaning of the watermelon and supermarket imagery is hard to pin down in this end of the world scene.
#
# 97:Both men sported looks of satisfaction I wonder if it's worth rewording to describe what this would look like? basked in a quiet room Basking sounds odd here.
#
# 98:another of her crying sessions -> another one of her crying sessions Uncontrollable sobbing came from her mouth. So we know sobbing can only come from her mouth. I think this can be tweaked to provide more about Jane0 the setting, or something else.
#
# 99:He looked up at LaRue -> Sam0 looked up at him It sounded awkward because the first He in the paragraph was LaRue slamming.
#
# 100:Ducky LaRue -> Ducky that LaRue I think a filler word here will be okay. He leaned forward on his stool in preparation to get up. -> He leaned forward on his stool to get up. I think you can trim this out because it's obvious and add some other detail to make the story interesting.
#
# 101:“Where you goin’?” LaRue said. -> “Where you goin’?” LaRue asked. This is optional. I've seen it written both ways in traditionally published books. Ya know, I gotta stick a gun in a guy’s face to get my money. I’m not some freakin’ white-collar criminal like you. I feel like you can mention this somewhere else. It takes away from the impact of the rest of the sentence.
#
# 102:This and pedophilia might be too much for some to pick up.
#
# 103:Suggested rewording. By now, he knew everyone who remained in the bar and had their exact positions memorize. Omit so. hyphenate ex-wife. Last sentence is OK but might be better if you had some verb you could put in after instead of R a.
#
# 104:Sounds like John0 was normally an alcohol-lover's fantasy. Make clear that the myriad of spirits is. Different from all his previous ones
#
# 105:Why would she asks this when it seems that Sam0 can work it? A
#
# 106:Spell LaRue the way you did before. It emitted as shrill humming sound. ten feet of the stone
#
# 107:You're telling me that John0 was a smart and perceptive kid, but I would prefer that you show me. What made him so smart? What makes him so perceptive? What's a passionless fight?
#
# 108:Ran a landscaping business when
#
# 109:Had moved out. Hadn't just moved out on his father but on him too.
#
# 110:Upset about missing the call. Not sure what you mean by never looked.
#
# 111:I think the spelling might be straitlaced
#
# 112:Who was bonding? John0 or Sam1 The first sentence and the third are the same.
#
# 113:She and John0 would have. Every day two words in this case.
#
# 114:Might be a start. its past
#
# 115:Use a lowercase letter for a before voice. Teaspoon one word
#
# 116:I don't understand his reasoning here, especially with respect to the student managers being seniors.
#
# 117:shouldn't base your college decision
#
# 118:Nevermind is not one word, but two, never mind.
#
# 119:In this paragraph, I can't tell if the first and second sentence are related or not. Like is the thick, gloppy mud why it's been nearly three weeks? Or is it just a coincidence? It seems like they'd be related since they're in the same paragraph, but they aren't worded in a way that is cause and effect.
#
# 120:The girl riding the Sam0 named Sam1 cantered next.—If it wasn't for your target age group, I'd say that you could probably cut 'the Sam0 named' from the sentence, because we know the only horse Sam3 didn't know the name of was the Sam0 but since your readers are younger, the repetition might be needed???? I really don't know.
#
# 121:Yeah for Jane0 being brave enough to ask for what she wants!
#
# 122:Again, I like this. That they don't care for Sam0 Sam1 and the Sam3 named Sam4 as they exited through the gate.—I'd for sure cut it this time. If you're worried that readers will think Sam4 is one of the teenage girls, then maybe change the horse's name.
#
# 123:Should Jane0 tell Sam1 what to do while Sam0 takes her turn? Does she keep Sam3 at a standstill in the center of the ring? Does she walk him around the arena?
#
# 124:Wow. That went downhill fast!! I'd expected Sam3 to feel guilty and offer to switch horses for John0's sake, but this is much better.
#
# 125:Hmm, is it still February? To say mom is 'still' living with Sam0 seems odd since it has likely just occurred in the last three weeks mentioned. Sam3 wouldn't have been able to move out that fast, so perhaps 'now' living with Sam0 Or had moved in with Sam0 instead of moving here. With her. Which I think is the point that Jane0 hates. Do you need the reminder that the trailer isn't her home anymore? It's only been the last chapter. I'm a bit on the fence about suggesting these changes, if you're hesitating. I know it's been a week since I've read the last chapter, but that won't be likely for other readers with a novel. Do you have more info on reviewing the events for Sam4 readers? I don't, so maybe this fits in.
#
# 126:Nice tension to have Sam0 ahead on lessons
#
# 127:Is that supposed to be coming from the man? It should be audible and in quotes, then.
#
# 128:Isn't it funny that in your story there's an Sam1 Sam2 and there are two in mine! I had a friend in Sam4 who had two who sadly got old and died, and then another. I've been and stayed with her and they are enormous dogs!
#
# 129:I like how you have one less willing pony and a less able rider for her to watch It's funny though, how horses know when they get an experienced rider and behave! If ever any of mine misbehaved in a lesson and I had to get on and make them be good, they never tried it on with me.
#
# 130:I don't think you need that comma because I feel 'old Sam0 is almost a compound noun and is the name she's calling him He's not boring and old - he's old Sam0 who is boring
#
# 131:I'm surprised her grandmother hasn't already taught her that. When my youngest had his first lessons (at the exceedingly crappy but well set up Sam0 riding school) they made no effort to teach him to rise to the trot, so I taught him at home in five minutes, and when he had his second lesson he was the only one who could do it.
#
# 132:I love her thoughts - yes, beat Sam0
#
# 133:I suggest: "We sped back into town and went to the bar above the basement where his target haunted and got a drink before the action." Very nitpicky of me.
#
# 134:Also super nitpicky, but I'd swap the second question mark with a period: "The last one.
#
# 135:Final nitpicky suggestion: I think shortening this to just "Like ghosts." would be punchier.
#
# 136:An intriguing opening. Nice use of a short sentence followed by a slightly longer paragraph - good variation a latent period where the person’s body appeared healthy, but their cells were damaged beyond repair so entirely that death followed - this is interesting, and quite disturbing acute radiation poisoning to eradicate ghosts - trying to get my head around this - seems like you temporarily create a new ghost (a 'walking ghost') in order to get rid of an actual ghost
#
# 137:John0 broke out in a chilled sweat - given it's not from John0's POV, this struck me as a little jarring. Would the protagonist be able to see John0's chilled sweat in the dingy basement? I think this would work better as 'I broke out in a chilled sweat'. Also, John0 seems pretty relaxed, so I'm surprised at the suggestion that he's sweating
#
# 138:You have what? Most people don't know what tinnitus is without looking it up. So why should we care? This is only your first line and you're already alienating readers.
#
# 139:'indicative of his work as a mercenary' I also don't know why 'mercenary' is italicized
#
# 140:on second read, what does the blood money have to do with Sam0's death ultimately? Just that he chooses to do it? It seems to hinge more on the misinterpretation of the antidote and how it works.
#
# 141:But she would have had a name before she died?
#
# 142:I had to wonder here about the relationship between John0 and the MC. I didn't get the idea they were so close as to have John0 leave behind the money in advance, especially if he believes he'll live to tell the tale. The MC felt more like an investigative reporter to me, strolling along to see what John0 does on this special case after they were able to witness a few "regular gigs".
#
# 143:The first time babe was used was fine, using it again so soon is a bit strange in my opinion.
#
# 144:This is gruesome. I love it. My only question is if this is Sam0's first mission, he seemed very confident in how everything works with walking. If this ISN'T Sam0's first mission, then wouldn't they know that the crystal/antidote doesn't cure the radiation poisoning? Just something to consider.
#
# 145:Not knowing this history very well before reading this chapter, it took some concentration for me to follow the twists and turns Sam15 these births and marriages and succession battles. But given the complexity, I think you manage to distill the key background information in an engaging fashion.
#
# 146:Wait a minute. I must be confused about dates. From the previous section I understood that Sam0 became King Sam8 Sam6 after the Sam7 Sam8 Sam9 in 1767. If he's 54, that means he was born in 1712-1713, so I guess I've got the chronology wrong.
#
# 147:This para could be made more concise. You mention that John0 ended his marriage to Jane0 twice in two sentences.
#
# 148:His parents left their young son behind in Sam0 Suggest you clarify who you're talking about. I didn't figure out that you meant that John0 left John1 until the following sentence.
#
# 149:Sam0 definitely sounds like a tyrant! I had to look up "morganatic".
#
# 150:I laughed at the part about the Sam3 folktales and Sam0 adaptations!
#
# 151:Had performed. I like genealogical gymnastics.
#
# 152:Maybe the information in the above paragraph and poem should come later. After you have told us more about the Sam1
#
# 153:His wife, Sam1 Indicate why he didn't want the parents present.
#
# 154:Great paragraph. Very interesting. I think it should be princess's. Somewhere you might give us a hint as to why she was married nine months after their marriage if they loathed each other. Maybe the loathing came later?
#
# 155:a son-in-law. I think the capital letter is needed for Sam8 before Sam3
#
# 156:I like it. A little confusing regarding chronology with respect to Jane0 The story seems to kind Sam3 double back to her. She's one Sam3 the most interesting people in this account for sure.
#
# 157:he said, - I suggest you let only the dialogue beats tag along after a character's line. For example, "A pretty name for a pretty lady." He grinned. This way the text gets less clunky because unnecessary dialogue tags are removed and the beats still make it clear to the reader who's talking, if there's any confusion at all.
#
# 158:Is the crow supposed to have a symbolic role? Perhaps it functions as a portent of death? This reminds me of the role of the raven in Sam0 mythology. The Sam1 regarded it as a manifestation of the goddess Morrigan, a harbinger of war and death.
#
# 159:Heroic or stupid?
#
# 160:He stood still, his arms at his sides like penguin flippers." No offense, I don't like this simile... I'm sorry!
#
# 161:If it were him, I'd have to assume he would've smelled this earlier. When he stops beside the lady and he has a foul smell waft past, it makes me think that it's either their surroundings or the woman.
#
# 162:Sam0 dashed towards a fence on the left.
#
# 163:From the first line, I think of her as a bird since you mentioned she "perched" on a bench. I love how you mention the leaf shaped shadows on her face. The sentence "Even in shade, the lady seemed to glow." is pretty, but could really be expanded upon.
#
# 164:Wherever this takes place (I suspect the Sam0 or Sam1 John0 is so fortunate to have chilly summers. Why is he so nervous to meet this lady? I feel as though he and his interest in her comes out of nowhere.
#
# 165:I'd change this a bit. John0 drummed his hands on the windowsill. "up and down seems" redundant here. The last line could possibly be cut. To me it's apparent that John0 wants to get to know her. I feel that John0 wants to know more than a little about her, so it seems a bit odd that he would be satisfied with just a little. Or you could just show us that he wants to know more about her and rewrite this line completely. You could establish this as John0's POV earlier.
#
# 166:John0's stomach churned as he spoke the first word.
#
# 167:He stepped back. The words sounded wrong once he spoke them.
#
# 168:Jane0 tried to return her brilliant smile. If you have a beat, you usually don't need a dialogue tag.
#
# 169:He glanced at the thick ice below Delphine's bench.
#
# 170:John0 flailed his hands.
#
# 171:again, I would say "she" instead of "the lady" since you just said that in the previous paragraph. Interesting book choice
#
# 172:I'm a bit confused by her reaction. Opening and closing her mouth doesn't seem to me like she's flattered, but Sam0 seems to think so.
#
# 173:What was happening? doesn't seem necessary here.
#
# 174:wait a second did she turn into a demon again and eat him?
#
# 175:He felt colour rush felt is a bad word. Maybe so: "The lady turned her head to smile at him. The last thing he needed now was to blush.
#
# 176:It is never mentioned where on Sam0 (assuming this is Sam0 so it's possible ice is common during the summer months. However, given that he did point out it was summer, does Sam2 find this continued existence of ice odd? Does it confuse him?
#
# 177:Again, not what I was expecting, and I am totaling here for it. I really want to see where this goes. mouth extended into a fleshy tunnel — I find this bit of description a little confusing. The mouth already opens up into a tunnel (throat), so are the jaw and throat both extending? Are the teeth filling the throat? Or is the mouth simply becoming larger and wider? as rows upon rows of gleaming white teeth assembled in Sam0's mouth — "Assembling" is a little generic. How are the teeth assembling? Are they growing? Are they popping into place? Are they morphing out of her existing teeth?
#
# 178:He vaulted over — Given the thick fur coat he is wearing, did he find it difficult to vault over the fence? How tall is this fence and what type of fence (wrought-iron, suburban home wooden fence, something else) is it?
#
# 179:Sam0 leant forwards, planted a kiss on her upper lip. — He mentioned in the previous paragraph it would be hard to get close. However, this sentence clearly shows it wasn't. Also, Jane0 wants him to get close so I'm guessing she would make it easy (as clearly she did given how easy he was able to physically touch her).
#
# 180:What did he expect her to be reading? I would be interested to know. It would help us get inside his mind and see what his idea of that lady is.
#
# 181:like an emperor penguin in a huddle Nice! She wasn’t as warm as he would have expected. How does he feel her warmth? What did he expect?
#
# 182:what did that guttural cry sound like?
#
# 183:How does he know she was seized by a spirit. I feel you could add some backstory and setting so we can understand what kind of world we are in. From the reader's point of view, it is not that obvious that Delphone was taken over by a bad spirit. She could also be a bad spirit herself. Why does Sam1 think that way?
#
# 184:How is she less beautiful? Description would have more impact. For example you could say: "You...save me?" Delphine said, rays of sunshine bouncing off her hairless skull..." Something like that. Just a thought.
#
# 185:Liking the kaleidoscope imagery
#
# 186:For a moment, this seems like a children's thing, but I don't know many kids who know what a proboscis is.
#
# 187:Close up of what? Even scripts have more than just dialog — they have description of what's going on. None of the scenes or characters here have any description, so it's hard to "see" the story in my head.

# %% [markdown]
# One commononality among successes is that they have long and descriptive reviews. Many of them also leak quotes from the passage into the review, which is bad (that is, some cases are claerly the model cheating). There does seem to be a lot of word matching happening.

# %%
for i, pair in enumerate(fail_pairs[:100]):
    print(str(i) + ": " + pair[1])
    print("")
# Out:
# 0:The change of pace to something slower and more intimate is good. Things weren't all bad before - just focusing on what seemed to be problems.
#
# 1:[quote] - like it
#
# 2:Mmm Perhaps Sam2 knows Jane0 so well that Jane0 was prepared to be extremely informal. It would be pretty lax of Jane0 though
#
# 3:Sam0 writer seems more comfortable with this, more relaxed, action.
#
# 4:As a reader, I'm more comfortable with this level of descriptiveness - as opposed to what feels to me like 'trying too hard' in the opening and the conclusion. However, it is a matter of taste.
#
# 5:Has she previously told John0 that her name is now Sam0 If so, the reader didn't know.
#
# 6:Nitpick" [he diesel engine’s horn] - an engine doesn't have a horn
#
# 7:Over the past several paragraphs, the filing of head-hopping has gone. I think it's because with the two characters interacting directly, the POV has moved slightly away from both of the, into a more third-person overview.
#
# 8:Excellent the issue of the room and the key was pre-laid in both threads. The reader is very much expecting something to come of it. It's on of those situations where even those readers who have not previously picked up on the significance of the key will tell themselves, 'I always knew that was going to happen.' Readers (including this one) love to be proved right. They're also in expectation of the characters realising the dilemma.
#
# 9:It's very discreet of the writer not to intrude on their privacy, but in a story that was always heading so clearly for a romantic involvement, it's a huge thing for the writer to jump from this point to Sam0 admiring the view again. A few paragraphs later, Sam0 imagines Sam1 asleep in Sam2's room, so perhaps nothing happened. Whether it didn't happen or just wasn't included in the story, the reader has a sense of anti-climax (place forgive the pun). The feeling is that there's definitely a chunk missing here.
#
# 10:I like the imagery involved with "scarlet remains of daylight.
#
# 11:This is a strong paragraph. You've managed to give a lot of background information without it feeling like a data dump.
#
# 12:This is an intriguing way to conclude the section.
#
# 13:Funny!
#
# 14:I like the sense of danger that is inherent with this scenario.
#
# 15:I like the rise of tension. You're doing a good job with the awkward exchange of dialogue.
#
# 16:How about [quote] yelled.
#
# 17:Clenched teeth instead of "grinding
#
# 18:Consider some sort of official break between sections, like an additional space or a #
#
# 19:I'm getting a stronger feeling of impending danger.
#
# 20:I wonder if Sam5 and Sam0 might know one another closely?
#
# 21:This is me being nitpicky, but since this is at nighttime, I think it would be better if she actually said "sorry" instead of mouthing it with swollen lips.
#
# 22:I'm amazed Jane0 would still want to get back to her party after all that.
#
# 23:This is getting awkward, lol
#
# 24:Wow, when is she going to get some sleep
#
# 25:I like the reveal she's going to L.A.
#
# 26:This line is interesting, implying that this takes place in the modern age. Though, these "steps" given are a little confusing and a bit of a cold open. Try introducing a bit more gradually and explain a bit more of what they are, and what exactly they're for. Also, the Intern seems like an interesting charter but try a describe her relation to the characters a bit more and what exactly she along with the main characters are doing
#
# 27:Great visuals, I could very easily see the scene and what these characters are doing, just try and describe each of them a bit more and who exactly they are, then its golden.
#
# 28:This had me completely confused. I didn't know where this action was coming from and it seemed a bit random. Try and explain what provoked this a bit more and the relation between Jane0 and Sam0 a bit more, because at this time I don't know a whole lot about either of them (except that Jane0 is coked out of her head) and why Sam0 simply standing in the doorway would provoke Jane0 and her daughters to attack.
#
# 29:again— the commas make the first sentence difficult to read.
#
# 30:was Sam3 earlier....
#
# 31:okay, so it's Sam2
#
# 32:scaring the heck—- may can show that to more humorous affect.
#
# 33:well show me what they are doing? are they getting dressed? that's sort of what i see.
#
# 34:if there is no mess, it seems like maybe they'd be confused at first...
#
# 35:maybe show me her face? the nastiness, how the age shows as she snarls....
#
# 36:maybe we should. unless she doesn't feel like part of the organization.
#
# 37:The opening is a little confusing. I'm not sure who they are, who the intern works for, or where this conversation takes place.
#
# 38:I like the description here. The wording works very well to set this scene.
#
# 39:them. ". Remember extra period between quotation marks and spoken words.
#
# 40:Extra space after "room," and the quotation marks.
#
# 41:I think this could be moved up to follow the sentence follow the intern making notes. It would make it clear that the intern is following Sam0 to avoid confusion.
#
# 42:Perhaps show Sam0's reaction to the disembodied voice.
#
# 43:Perhaps specify that the intern says this. For a second, I thought the mom was responding to Sam0
#
# 44:The dialogue here feels repetitive.
#
# 45:Who says this?
#
# 46:What is the new interns reaction to this?
#
# 47:[quote] You can lose the 'so' to give the line more impact.
#
# 48:This is pretty funny
#
# 49:Sam2's name seems to change to Sam0 and back several times throughout the story. I don't know if Sam0 is a common nickname for Sam2 but I think you should pick one name and stick to it.
#
# 50:[quote] Awkward phrasing
#
# 51:Not sure what this line is supposed to mean - talk to research about what?
#
# 52:The line needs to end with a full stop, not a comma
#
# 53:[quote] Awkward phrasing
#
# 54:This line is funny
#
# 55:[quote] needs commas I'm not sure who Sam1 is referring to - Sam0 Why are they planning to murder Sam0
#
# 56:[quote] Punctuation
#
# 57:Funny line
#
# 58:This is rather sudden.
#
# 59:Now I feel a bit sorry for the villains?
#
# 60:This is a logic nit pick, but I don't think that would put Sam1 in the clear. She was still in the house when the crime happened, and is pretty much the sole beneficiary.
#
# 61:[quote] comma
#
# 62:Is this implying that the last intern killed the previous director??
#
# 63:Going for the Sam1 story line then. Also, are you going third person here?
#
# 64:At who? She just jumping and kicking for the fun of it? By how much does she miss?
#
# 65:Remove the period from the dialog. (hate when I have stupid blips like this in my works. Drives me batty.)
#
# 66:Her saying I'm sorry makes no sense, as well as why they attacked her. You might need a little more setup of that. Maybe a sentence or two.
#
# 67:Are they talking like the twins from the shining? have one or the other say it. You can give the other a nod or some other body movement.
#
# 68:I am on the fence about how to make this more effective. I almost want the intern stuff italicized or in bold or something. It feels disjointed.
#
# 69:Draw this out a little more. Where is Jane0 standing how is she looking at the room.
#
# 70:This is a super abrupt shift. You leave Jane0 in the dinning room, then an "instant" later we are back with Jane1 and her girls all of a sudden. Are we in the dinning room or the room they were in originally? And who's room did we start out in. This is a very jarring scene change.
#
# 71:Little confused. is holly and harmony the same person? I had to go back and take a look. Think they are, but just want to make sure. Depending on how you are writing, you can always do a word search to fix a name change.
#
# 72:Something that I am noticing is that you are explaining a lot of the tags. Most of the time this isn't exactly bad, but you could be more productive with changing some of the tags around. Also, you need a period between girls and she or lowercase she and comma between girls and she.
#
# 73:Comma between now and how. Give that moment pause in talking. Like [quote]
#
# 74:her and she who? the intern or Jane0
#
# 75:I'm intrigued! Great opening!
#
# 76:though I like everything about this first sentence, it's a very long sentence strung together with a lot of commas. I think splitting it up would keep that same impact but help the logistical flow of it, if that makes sense?
#
# 77:your tense feels like it's flip flopping a lot—the intern HAS, they SAID, Sam0 SAYS—make sure you're staying consistent. If this is purposely stylized this way, tense is a tough "rule" to fudge because messing with it can mess with the flow and feel of the story and the reader's ability to understand and follow. And oftentimes, if tense is off, even someone not well versed in the "rules" of writing can pick up on the fact that something's a little weird.
#
# 78:the intern, the prospect—I'm a little confused who is who since you've given us 5 characters in not a lot of time
#
# 79:Okay, so I think this confirms there are two daughters (excluding Sam1 but you've got one named both Sam0 and Sam2 (to go with Sam3 For what it's worth, I prefer Sam2 to Sam0 for the additional irony.
#
# 80:Ah okay—this is a spin on Sam3 Very interesting! I'm guessing the "intern" will be the fairy god mother? And this sudden violence feels a little out of the blue here—like 0 to 60 in nothing.
#
# 81:I'd break Sam0's dialogue and Sam1's action into 2 separate paragraphs here
#
# 82:they say this completely together? kind of creepy...
#
# 83:until this moment, I didn't realize the intern was observing this scene—maybe make that clearer earlier on?
#
# 84:feels a little strange that she's just saying this out loud to herself?
#
# 85:back? Wait, where's she going? I'm confused
#
# 86:This confused me—I think you might be better off following the intern directly to the aunt and sisters because this line really threw me off. We're with Jane0 "I'll be back", then she's back made no sense to me, especially because at the end you have Jane0 follow the gunshot upstairs
#
# 87:so the intern went and made it so Jane0 and the daughters did all this cocaine? unclear. And why'd we switch away from Sam0 and right back so quickly?
#
# 88:WOAH!!
#
# 89:this dialogue feels a little clunky, like it's been written but not "spoken" if that makes sense. I always try to read my dialogue out loud to myself to hear if it sounds natural and that really helps smooth the rough edges dialogue can get sometimes
#
# 90:who says this?
#
# 91:WOAH!! this fairy godmother intern is BRUTAL!
#
# 92:lol—so much character packed into this one action—nice!
#
# 93:a rogue fairy godmother! I love it!
#
# 94:woah!! great ending!!
#
# 95:Is this the intern speaking? If so, since you already use the pronoun "her" in the first sentence, I'd say "she said" here. If it's not the intern speaking, then I don't know who "they" are.
#
# 96:Is that supposed to be Sam0 and Sam3 Also, is this a Sam4 story?
#
# 97:Is he descending down the hole? I m still unclear about the setting and where the character is? Inside the passage? Outside/inside the hole? just at the mouth of the passage?
#
# 98:Here, you made some of my doubts clear, but the later part once again confused me
#
# 99:Things are clear and I visualized him in the tunnel and willing to return to the room by closing the passage door

# %% [markdown]
# Many of the fail cases seem to have short and unspecific comments (i.e. good ending, lol, WOAH!, punctuation, awkward phrasing) which could apply to any story.

# %%
print(success_pairs[185][0])
# Out:
# In a world where butterflies rule the skies during their annual Sam0 migration over Sam1 their massive, groovy kaleidoscope gets knocked off course in a storm, and flies smack into…
